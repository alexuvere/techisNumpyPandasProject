# %% [markdown]
# <a href="https://colab.research.google.com/github/alexuvere/techisNumpyPandasProject/blob/main/_Assignment_PANDAS_NUMPY_checkpoint.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np 
array_1d = np.zeros(3)
print(array_1d)


a = np.random.randint(2,10, (3,4))
b = np.random.randint(2,10, (4,3))
print (a)
print(b)
# Out:
# [0. 0. 0.]
# [[6 3 5 5]
#  [9 6 6 7]
#  [6 3 2 4]]
# [[3 7 4]
#  [9 2 2]
#  [7 6 6]
#  [6 3 3]]

# %%
a.dot(b)
# Out:
# array([[110,  93,  75],
#        [165, 132, 105],
#        [ 83,  72,  54]])

# %%
# READ THE CSV FILE PROVDED using pandas and display the first 5entries 

import pandas as pd 

data = pd.read_csv('/content/drive/MyDrive/data.csv')


data.head

# %%
# Describe the data with all features.
data.describe()
# Out:
#         OBJECTID        ACRES  SHAPE.AREA  SHAPE.LEN
# count  25.000000    25.000000   25.000000  25.000000
# mean   33.000000   724.134400    0.000352   0.109863
# std     7.359801  1275.490247    0.000617   0.089073
# min    21.000000    11.400000    0.000005   0.009396
# 25%    27.000000    72.300000    0.000034   0.033885
# 50%    33.000000   524.810000    0.000256   0.087192
# 75%    39.000000   836.470000    0.000399   0.145220
# max    45.000000  6492.930000    0.003136   0.338800

# %%
#Find the total count of missing values for each feature.
data.sum()
# Out:
# OBJECTID                                                     825
# UNIT_NAME      Fort Stevenson State ParkBeaver Lake State Par...
# DESCRIPTION    State ParkState ParkState ParkState ParkState ...
# ACRES                                                   18103.36
# SHAPE.AREA                                                0.0088
# SHAPE.LEN                                               2.746584
# dtype: object

# %%
data.isnull().sum()
# Out:
# OBJECTID       0
# UNIT_NAME      0
# DESCRIPTION    0
# ACRES          0
# SHAPE.AREA     0
# SHAPE.LEN      0
# dtype: int64

# %%
#Display all the unique values from the 'DESCRIPTION’ column.
data.DESCRIPTION.unique()
# Out:
# array(['State Park', 'Interpretive Center', 'State Recreation Area',
#        'State Natural Area', 'State Nature Preserve'], dtype=object)

# %%
# Create a grouped table usin 'DESCRIPTION' as the grouping columns with the means of all the other columns.
data.groupby("DESCRIPTION").mean()
# Out:
#                         OBJECTID        ACRES  SHAPE.AREA  SHAPE.LEN
# DESCRIPTION
# Interpretive Center    29.000000    14.710000    0.000007   0.016774
# State Natural Area     39.000000   219.615000    0.000105   0.077137
# State Nature Preserve  39.500000    84.095000    0.000041   0.037175
# State Park             28.538462  1168.668462    0.000567   0.150326
# State Recreation Area  38.285714   326.934286    0.000162   0.078135

# %%
#Generate a random sample of 10 rows from the data.
import random
random.random_sample(data, size=10)

# %%
data.sample(n=10)
# Out:
#     OBJECTID                              UNIT_NAME            DESCRIPTION  \
# 22        44  Turtle Mountain State Recreation Area  State Recreation Area
# 12        35   Butte St. Paul State Recreation Area  State Recreation Area
# 14        33                Turtle River State Park             State Park
# 3         24                 Fort Ransom State Park             State Park
# 4         25              Grahams Island State Park             State Park
# 21        43    Pembina Gorge State Recreation Area  State Recreation Area
# 5         26                   Icelandic State Park             State Park
# 15        34              Lake Sakakawea State Park             State Park
# 1         22                 Beaver Lake State Park             State Park
# 24        42    Pelican Point State Recreation Area  State Recreation Area
#
#       ACRES  SHAPE.AREA  SHAPE.LEN
# 22   695.04    0.000345   0.086487
# 12    51.23    0.000025   0.022095
# 14   775.28    0.000378   0.145220
# 3    933.78    0.000444   0.128733
# 4    959.33    0.000469   0.125546
# 21  1236.98    0.000615   0.338800
# 5    930.30    0.000461   0.166712
# 15   739.52    0.000357   0.191806
# 1    273.16    0.000129   0.080067
# 24    25.22    0.000013   0.026357

# %%
from pandas.core.internals.managers import new_block
# Add a Feature called 'New_feature' to the new Dataset and Add Random float Values in between 0 and 1 using Numpy. 
data.shape
# Out:
# (25, 6)

# %%
data['new_feature'] = np.random.rand(25, 1)

# %%
data
# Out:
#     OBJECTID                                   UNIT_NAME  \
# 0         21                   Fort Stevenson State Park
# 1         22                      Beaver Lake State Park
# 2         23             Fort Abraham Lincoln State Park
# 3         24                      Fort Ransom State Park
# 4         25                   Grahams Island State Park
# 5         26                        Icelandic State Park
# 6         27                   Lake Metigoshe State Park
# 7         28                  Lewis and Clark State Park
# 8         29         Lewis and Clark Interpretive Center
# 9         30           Fort Mandan State Recreation Area
# 10        31                  Little Missouri State Park
# 11        32                      Sully Creek State Park
# 12        35        Butte St. Paul State Recreation Area
# 13        36       Crow Flies High State Recreation Area
# 14        33                     Turtle River State Park
# 15        34                   Lake Sakakawea State Park
# 16        37                  Elkhorn State Natural Area
# 17        38         Fahlgren Park State Recreation Area
# 18        39             Gunlogson State Nature Preserve
# 19        40  Head of the Mountain State Nature Preserve
# 20        41           Missouri River State Natural Area
# 21        43         Pembina Gorge State Recreation Area
# 22        44       Turtle Mountain State Recreation Area
# 23        45                      Cross Ranch State Park
# 24        42         Pelican Point State Recreation Area
#
#               DESCRIPTION    ACRES  SHAPE.AREA  SHAPE.LEN  new_feature
# 0              State Park   586.48    0.000284   0.135641     0.448386
# 1              State Park   273.16    0.000129   0.080067     0.861662
# 2              State Park   836.47    0.000399   0.119868     0.599880
# 3              State Park   933.78    0.000444   0.128733     0.192423
# 4              State Park   959.33    0.000469   0.125546     0.762061
# 5              State Park   930.30    0.000461   0.166712     0.128835
# 6              State Park  1508.53    0.000751   0.212196     0.567112
# 7              State Park   524.81    0.000256   0.130420     0.775077
# 8     Interpretive Center    14.71    0.000007   0.016774     0.643007
# 9   State Recreation Area    11.40    0.000005   0.009396     0.806652
# 10             State Park  6492.93    0.003136   0.313756     0.313055
# 11             State Park    63.03    0.000030   0.024016     0.376670
# 12  State Recreation Area    51.23    0.000025   0.022095     0.805433
# 13  State Recreation Area   247.11    0.000120   0.050518     0.047304
# 14             State Park   775.28    0.000378   0.145220     0.304244
# 15             State Park   739.52    0.000357   0.191806     0.201459
# 16     State Natural Area   264.84    0.000127   0.067082     0.369200
# 17  State Recreation Area    21.56    0.000010   0.013294     0.059192
# 18  State Nature Preserve    95.89    0.000048   0.040465     0.579249
# 19  State Nature Preserve    72.30    0.000034   0.033885     0.323735
# 20     State Natural Area   174.39    0.000083   0.087192     0.230722
# 21  State Recreation Area  1236.98    0.000615   0.338800     0.616191
# 22  State Recreation Area   695.04    0.000345   0.086487     0.948984
# 23             State Park   569.07    0.000274   0.180257     0.134835
# 24  State Recreation Area    25.22    0.000013   0.026357     0.589401

# %%
# Replace zero value of column 'OBJECTID' with mean value permanently. 
data.replace(data['OBJECTID' ]==0, data['OBJECTID'].mean())
# Out:
#     OBJECTID                                   UNIT_NAME  \
# 0         21                   Fort Stevenson State Park
# 1         22                      Beaver Lake State Park
# 2         23             Fort Abraham Lincoln State Park
# 3         24                      Fort Ransom State Park
# 4         25                   Grahams Island State Park
# 5         26                        Icelandic State Park
# 6         27                   Lake Metigoshe State Park
# 7         28                  Lewis and Clark State Park
# 8         29         Lewis and Clark Interpretive Center
# 9         30           Fort Mandan State Recreation Area
# 10        31                  Little Missouri State Park
# 11        32                      Sully Creek State Park
# 12        35        Butte St. Paul State Recreation Area
# 13        36       Crow Flies High State Recreation Area
# 14        33                     Turtle River State Park
# 15        34                   Lake Sakakawea State Park
# 16        37                  Elkhorn State Natural Area
# 17        38         Fahlgren Park State Recreation Area
# 18        39             Gunlogson State Nature Preserve
# 19        40  Head of the Mountain State Nature Preserve
# 20        41           Missouri River State Natural Area
# 21        43         Pembina Gorge State Recreation Area
# 22        44       Turtle Mountain State Recreation Area
# 23        45                      Cross Ranch State Park
# 24        42         Pelican Point State Recreation Area
#
#               DESCRIPTION    ACRES  SHAPE.AREA  SHAPE.LEN  new_feature
# 0              State Park   586.48    0.000284   0.135641     0.448386
# 1              State Park   273.16    0.000129   0.080067     0.861662
# 2              State Park   836.47    0.000399   0.119868     0.599880
# 3              State Park   933.78    0.000444   0.128733     0.192423
# 4              State Park   959.33    0.000469   0.125546     0.762061
# 5              State Park   930.30    0.000461   0.166712     0.128835
# 6              State Park  1508.53    0.000751   0.212196     0.567112
# 7              State Park   524.81    0.000256   0.130420     0.775077
# 8     Interpretive Center    14.71    0.000007   0.016774     0.643007
# 9   State Recreation Area    11.40    0.000005   0.009396     0.806652
# 10             State Park  6492.93    0.003136   0.313756     0.313055
# 11             State Park    63.03    0.000030   0.024016     0.376670
# 12  State Recreation Area    51.23    0.000025   0.022095     0.805433
# 13  State Recreation Area   247.11    0.000120   0.050518     0.047304
# 14             State Park   775.28    0.000378   0.145220     0.304244
# 15             State Park   739.52    0.000357   0.191806     0.201459
# 16     State Natural Area   264.84    0.000127   0.067082     0.369200
# 17  State Recreation Area    21.56    0.000010   0.013294     0.059192
# 18  State Nature Preserve    95.89    0.000048   0.040465     0.579249
# 19  State Nature Preserve    72.30    0.000034   0.033885     0.323735
# 20     State Natural Area   174.39    0.000083   0.087192     0.230722
# 21  State Recreation Area  1236.98    0.000615   0.338800     0.616191
# 22  State Recreation Area   695.04    0.000345   0.086487     0.948984
# 23             State Park   569.07    0.000274   0.180257     0.134835
# 24  State Recreation Area    25.22    0.000013   0.026357     0.589401
